# %% [markdown]
# # CH06.Frameworks

# %% [markdown]
# ## 1. Overview
# > A program that provides various elements and manual rules for developing a specific program

# %% [markdown]
# ## 2. FastAPI

# %% [markdown]
# 1. Nano template setup
#
# ```shell
# $ pip3 install cookiecutter
# $ cookiecutter https://github.com/rednafi/fastapi-nano.git
# ```
#
# 2. Docker setup
#
# ```shell
# $ docker-compose up -d
# ```
#
# 3. Show in browser
#
# [http://127.0.0.1:5000/](http://127.0.0.1:5000/)
#
# 4. Automatic API Docs
#
# [http://127.0.0.1:5000/docs/](http://127.0.0.1:5000/docs/)

# %% [markdown]
# ## 3. Setup backend
