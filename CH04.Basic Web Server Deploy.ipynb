# %% [markdown]
# # CH04.Basic Web Server Deploy

# %% [markdown]
# ## 1. Compile, Build, and Release
#
# 1. Compile
#
# > It is the process of converting source code into machine language that a computer can understand.
#
# 2. Build
#
# > Building the compiled code into an executable state is called Build.
#
# 3. Deploy
#
# > Placing the built-in executable file in an environment accessible by users

# %% [markdown]
# ## 2. CI/CD
#
# 1. CI(Continuous Integration)
#
# > Automation of build and test
#
# 2. CD(Continuous Deploy)
#
# > Automation of deployment
#
# 3. Solutions
#
# > Circle CI, Travis and Jenkins

# %% [markdown]
# ## 3. Simple HTTP Server
#
# Refer to the class content

# %% [markdown]
# ## 4. IPv4
#
# ```
# 0000 0000 0000 0000 0000 0000 0000 0000
# 1111 1111 1111 1111 1111 1111 1111 1111
# ```
#
# > 4.3 billions of addressing
#
# 1. IPv4 Classes(NetworkID/HostID)
#
# - A : ``` 1.0.0.1 ~ 126.255.255.254 ``` : __0xxx xxxx__ . xxxx xxxx . xxxx xxxx . xxxx xxxx
# - B : ``` 128.0.0.1 ~ 191.255.255.254 ``` : __10xx xxxx . xxxx xxxx__ . xxxx xxxx . xxxx xxxx
# - C : ``` 192.0.0.1 ~ 223.255.255.254 ``` : __110x xxxx . xxxx xxxx . xxxx xxxx__ . xxxx xxxx
#
# ![https://airoserver.com/wp-content/uploads/2019/10/What-is-Subnet-mask-1.jpg](https://airoserver.com/wp-content/uploads/2019/10/What-is-Subnet-mask-1.jpg)
#
# 2. CIDR(Classless InterDomain Routing), Subnet, and Subnet mask(Prefix)
#
# - Address format : a.b.c.d/x
#
# ![https://www.bestproxyreviews.com/wp-content/uploads/2021/03/IPv4-Subnetting.jpg](https://www.bestproxyreviews.com/wp-content/uploads/2021/03/IPv4-Subnetting.jpg)
#
# 3. NetworkIP/BroadcastIP
#
# Take a note.
#
# 4. Special addresses
# - ``` 0.0.0.0/8 ``` : 자체
# - ``` 10.0.0.0/8 ``` : 사설
# - ``` 172.16.0.0/12 ``` : 사설
# - ``` 192.168.0.0/16 ``` : 사설
# - ``` 127.0.0.0/8 ``` : 뤂백

# %% [markdown]
# ## 5. Port forwarding
#
# ![https://upload.wikimedia.org/wikipedia/commons/thumb/5/5f/NAPT-en.svg/1200px-NAPT-en.svg.png](https://upload.wikimedia.org/wikipedia/commons/thumb/5/5f/NAPT-en.svg/1200px-NAPT-en.svg.png)
#
# Let's do it!

# %% [markdown]
# ## 6. DNS(Domain Name Service)
#
# > Domain to IP Address service.
#
# Therfore, there are DNS server.

# %%
# !nslookup www.google.com

# What is IPv6?
# Out:
# Server:		127.0.0.53
# Address:	127.0.0.53#53
#
# Non-authoritative answer:
# Name:	www.google.com
# Address: 142.250.207.68
# Name:	www.google.com
# Address: 2404:6800:4005:820::2004

# %%
# !nslookup www.naver.com
# Out:
# Server:		127.0.0.53
# Address:	127.0.0.53#53
#
# Non-authoritative answer:
# www.naver.com	canonical name = www.naver.com.nheos.com.
# Name:	www.naver.com.nheos.com
# Address: 223.130.195.95
# Name:	www.naver.com.nheos.com
# Address: 223.130.195.200
