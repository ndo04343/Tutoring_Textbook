# %% [markdown]
# # CH01. Basic Unix System
#
# You must take a note because this textbook doesn't enough for you.

# %% [markdown]
# ## 1. Unix based OS

# %% [markdown]
# 1. Linux
#     1. Linux(Ubuntu) : 46%
#     2. Linux(Centos) : 18%
#     3. Linux(Debian) : 17%
#     4. Linux(Red Hat) : 2%
# 2. Mac OS

# %% [markdown]
# ## 2. Linux process
#
# Linux is multi-user operating system. Following is general process of linux user.
# 1. Login
# 2. Execute program
# 3. Logout

# %% [markdown]
# - Login
#
# ```shell
# $ login
# login: leibniz21c
# Password:
# Last login: Fri Aug 20 15:08:59 on ttys001
# -------------------
# Hello Heesung Yang!
# -------------------
# Ready to use env :
# 1. flutter
# 2. lab
# 3. docker
# -------------------
# leibniz21c@Heesungui-MacBookPro ~%
# ```
#
# - Execute program
#
# ```shell
# leibniz21c@Heesungui-MacBookPro ~ % ./helloworld
# Hello world!
# leibniz21c@Heesungui-MacBookPro ~ %
# ```
#
# - Logout
#
# ```shell
# leibniz21c@Heesungui-MacBookPro ~ % logout
# Saving session...
# ...copying shared history...
# ...saving history...truncating history files...
# ...completed.
#
# [프로세스 완료됨]
#
# ...
#
# leibniz21c@Heesungui-MacBookPro ~ % exit
# Saving session...
# ...copying shared history...
# ...saving history...truncating history files...
# ...completed.
#
# [프로세스 완료됨]
#
# ```
#
# How can we know "who am I?"
#
# ```shell
# leibniz21c@Heesungui-MacBookPro ~ % who am i
# leibniz21c ttys001  Aug 20 15:19
# leibniz21c@Heesungui-MacBookPro ~ % who
# leibniz21c console  Aug 20 14:47
# leibniz21c ttys000  Aug 20 14:48
# leibniz21c ttys001  Aug 20 15:19
# leibniz21c@Heesungui-MacBookPro ~ %
# ```
#
# How can we stop infinity looping process?
# ```
# leibniz21c@Heesungui-MacBookPro ~ % cat > 1
# qwerty^C
# leibniz21c@Heesungui-MacBookPro ~ %
# ```

# %% [markdown]
# ## 3. Unix File System

# %% [markdown]
# 1. Tree based structure
#
# ```shell
# leibniz21c@Heesungui-MacBookPro / % tree -L 1 -N /
# /
# ├── Applications
# ├── Library
# ├── System
# ├── Users
# ├── Volumes
# ├── bin
# ├── cores
# ├── dev
# ├── etc -> private/etc
# ├── home -> /System/Volumes/Data/home
# ├── opt
# ├── private
# ├── sbin
# ├── tmp -> private/tmp
# ├── usr
# └── var -> private/var
# ```
#
# 2. Basic
#     1. Path
#         - Absolute path
#         - Relative path
#     2. File/Directory
#     3. Hidden file
#     4. Home directory
#
#
# 3. Commands
#
# - List
#
# ```shell
# leibniz21c@Heesungui-MacBookPro / % ls
# Applications	System		Volumes		cores		etc		opt		sbin		usr
# Library		Users		bin		dev		home		private		tmp		var
#
# ```
#
# - Change Directory
#
# ```shell
# leibniz21c@Heesungui-MacBookPro / % cd /usr
# leibniz21c@Heesungui-MacBookPro /usr %
# leibniz21c@Heesungui-MacBookPro /usr % cd ~
# leibniz21c@Heesungui-MacBookPro ~ %
# ```
#
# - Concatenate
#
# ```shell
# leibniz21c@Heesungui-MacBookPro ~ % cat helloworld.c
# #include <stdio.h>
#
# int main(void)
# {
# 	printf("Hello world!\n");
# }
# leibniz21c@Heesungui-MacBookPro ~ %
# ```
#
# - Manual
#
# ```
# EXAMPLES
#      The command:
#
#            cat file1
#
#      will print the contents of file1 to the standard output.
#
#      The command:
#
#            cat file1 file2 > file3
#
#      will sequentially print the contents of file1 and file2 to the file file3, truncating file3 if it already exists.  See the manual page
#      for your shell (i.e., sh(1)) for more information on redirection.
#
#      The command:
#
#            cat file1 - file2 - file3
#
#      will print the contents of file1, print data it receives from the standard input until it receives an EOF (`^D') character, print the
#      contents of file2, read and output contents of the standard input again, then finally output the contents of file3.  Note that if the
#      standard input referred to a file, the second dash on the command-line would have no effect, since the entire contents of the file would
#      have already been read and printed by cat when it encountered the first `-' operand.
# ```
#
# - Print Working Directory
#
# ```shell
# leibniz21c@Heesungui-MacBookPro ~ % pwd
# /Users/leibniz21c
# leibniz21c@Heesungui-MacBookPro ~ %
# ```
#
# - Make Directory
#
# ```shell
# leibniz21c@Heesungui-MacBookPro ~ % mkdir myDir
# leibniz21c@Heesungui-MacBookPro ~ % cd myDir
# leibniz21c@Heesungui-MacBookPro myDir %
# ```
#
# - Remove Directory
#
# ```shell
# leibniz21c@Heesungui-MacBookPro ~ % rmdir myDir
# leibniz21c@Heesungui-MacBookPro ~ %
# ```
#
# - Copy
#
# ```shell
# leibniz21c@Heesungui-MacBookPro ~ % cp main.c newMain.c
# leibniz21c@Heesungui-MacBookPro ~ % ls
# main.c  	newMain.c
# leibniz21c@Heesungui-MacBookPro ~ %
# ```
#
# - Remove
#
# ```shell
# leibniz21c@Heesungui-MacBookPro ~ % rm main.c
# leibniz21c@Heesungui-MacBookPro ~ % ls
# newMain.c
# ```
#
# - Move(or rename)
#
# ```shell
# leibniz21c@Heesungui-MacBookPro ~ % ls
# myfile.c     mydir
# leibniz21c@Heesungui-MacBookPro ~ % mv myfile.c mydir
# leibniz21c@Heesungui-MacBookPro ~ % ls mydir
# myfile.c
# leibniz21c@Heesungui-MacBookPro ~ % mv mydir/myfile.c mydir/newFile.c
# leibniz21c@Heesungui-MacBookPro ~ % ls mydir
# newFile.c
# leibniz21c@Heesungui-MacBookPro ~ %
# ```

# %% [markdown]
# ## 4. Shell

# %% [markdown]
# 1. What is shell?
#
# > bridge between user and kernel.
#
# 2. Shell script
#
# ```
# leibniz21c@Heesungui-MacBookPro ~ % cat myScript.sh
# mkdir myDir
# cd myDir
# mkdir m1
# mkdir m2
# mkdir m3
# ls
# leibniz21c@Heesungui-MacBookPro ~ % sh myScript.sh
# m1	m2	m3
# leibniz21c@Heesungui-MacBookPro ~ %
# ```
#
# 3. Variable
#
# - Using variable
# ```shell
# leibniz21c@Heesungui-MacBookPro ~ % A="HELLO_WORLD"
# leibniz21c@Heesungui-MacBookPro ~ % echo $A
# HELLO_WORLD
# leibniz21c@Heesungui-MacBookPro ~ %
# ```
#
# - Export variable
#
# ```shell
# leibniz21c@Heesungui-MacBookPro ~ % export A
# leibniz21c@Heesungui-MacBookPro ~ % env
#
# ...
#
# PATH=/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/usr/local/go/bin:/Library/Apple/usr/bin:/Users/leibniz21c/dev:/Users/leibniz21c/dev/flutter/bin
#
# ...
#
# PWD=/Users/leibniz21c
#
# ...
#
# A=1
# LANG=ko_KR.UTF-8
#
# ...
# leibniz21c@Heesungui-MacBookPro ~ %
#
# ```
#
# - What is your shell?
#
# ```
# leibniz21c@Heesungui-MacBookPro ~ % echo $0
# -zsh
# leibniz21c@Heesungui-MacBookPro ~ % echo $SHELL
# /bin/zsh
# leibniz21c@Heesungui-MacBookPro ~ %
# ```
#
# - Z-shell resource file.
#
# ```
# # See ~/.zshrc
# ````
#
# - Examples Shell scripts
#
# ```shell
# #!/bin/bash
# #
# #       LISA Enviroment Constructor
# #       2020.11.19 Team LISA
# #
#
# # Init and print information
# echo "--------------------------------------------------"
# echo "                 Welcome to LISA                  "
# echo "--------------------------------------------------"
# echo "Lisa Header enviroment constructor : version.1.0.0"
# echo "System Shall : "$BASH
# echo "System Shall version : "$BASH_VERSION
# echo "System OS : "$OSTYPE
# echo "User name : "$USERNAME
# echo "[Warning] You must have curl."
#
# # get docker code by https://get.docker.com
# curl -sSL https://get.docker.com | sh
#
# # change socket permission
# sudo chmod 666 /var/run/docker.sock
#
# # Get Mode
# echo "Is this device Header node?(y/n) : "
# read mode
#
# if [ "Y" = $mode ] || [ "y" = $mode ]
# then
#     # Header node
#     docker swarm init > token_info.txt
#     echo "Check the token at token_info.txt"
# else
#     # Worker node
#     echo "Press the token : "
#     read token
#     echo "Press the domain or IP : "
#     read addr
#     echo "Press the port number : "
#     read port
#
#     docker swarm join --token $token $addr:$port
# fi
#
# echo "Complete!"
# ```

# %% [markdown]
# ## 5. Packages manager
# __Dependency management__ ! You have to remember it!

# %% [markdown]
# ### 1. OS
# 1. Linux
#     - Debian based
#         1. Low-level : dpkg
#         2. High-level : apt-get
#     - CentOS
#         1. Low-level : rpm
#         2. High-level : yum
# 2. Mac OS
#     - HomeBrew

# %% [markdown]
# ### 2. Language
#
# 1. Python
#     - pip - PyPI
# 2. Java
#     - Maven, Gradle - Maven
# 3. Node.js
#     - npm - NPM
